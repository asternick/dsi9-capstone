# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/methane-emissions-by-sector-gg-coe.csv")

# %%
df.head()
# Out:
#         Entity Code  Year  Energy (tonnes)  Industry (tonnes)  \
# 0  Afghanistan  AFG  1961              NaN                NaN
# 1  Afghanistan  AFG  1962              NaN                NaN
# 2  Afghanistan  AFG  1963              NaN                NaN
# 3  Afghanistan  AFG  1964              NaN                NaN
# 4  Afghanistan  AFG  1965              NaN                NaN
#
#    Residential & commercial (tonnes)  Other sources (tonnes)  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
#
#    Land use (tonnes)  Agriculture (tonnes)  Waste (tonnes)  \
# 0                NaN             6001365.4             NaN
# 1                NaN             6108210.1             NaN
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Entity Code  Year  Energy (tonnes)  Industry (tonnes)  \
# 0      Afghanistan  AFG  1961              NaN                NaN
# 1      Afghanistan  AFG  1962              NaN                NaN
# 2      Afghanistan  AFG  1963              NaN                NaN
# 3      Afghanistan  AFG  1964              NaN                NaN
# 4      Afghanistan  AFG  1965              NaN                NaN
# ...            ...  ...   ...              ...                ...
# 13808     Zimbabwe  ZWE  2012              NaN                NaN
# 13809     Zimbabwe  ZWE  2013              NaN                NaN
# 13810     Zimbabwe  ZWE  2014              NaN                NaN
# 13811     Zimbabwe  ZWE  2030              NaN                NaN
# 13812     Zimbabwe  ZWE  2050              NaN                NaN
#
#        Residential & commercial (tonnes)  Other sources (tonnes)  \
# 0                                    NaN                     NaN
# ...
