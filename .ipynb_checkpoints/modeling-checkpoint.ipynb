# %% [markdown]
# # Imports

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use('ggplot')

# %% [markdown]
# Here we read in our two .csv files which represent the electricity rates and generation data:

# %%
dfr = pd.read_csv('./data/electricity-rates.csv')
dfg = pd.read_csv('./data/electricity-generation.csv')

# %%
dfg.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# # Merging into one DataFrame

# %% [markdown]
# Separate preprocessing of rates and generation data is complete. The next step is to merge all the meaningful data into one dataframe. First, we will confirm the two dataframes have the same Year and State order:

# %%
dfg['Year'].equals(dfr['Year'])
# Out:
# True

# %%
dfr['State'].equals(dfr['State'])
# Out:
# True

# %% [markdown]
# The only data we need from the rates dataframe is Cents_kWh. Here we add it to the generation dataframe:

# %%
dfg['Cents_kWh'] = dfr['Cents_kWh_Inf_Adj']

# %%
dfg.head()
# Out:
#    Year State      Coal  Geothermal  Hydroelectric  Natural Gas   Nuclear  \
# 0  1990    AK    510573           0         974521      3466261         0
# 1  1990    AL  53658115           0       10366507      1020714  12051882
# 2  1990    AR  19207935           0        3654653      3578573  11282053
# 3  1990    AZ  31915610           0        7417576      2333900  20597689
# 4  1990    CA   2637677    14521254       23792567     74168308  32692807
#
#    Other  Other Gases  Petroleum  Solar Thermal/PV      Total     Wind  \
# 0      0            0     497116                 0    5599506        0
# 1      0       269476     138089                 0   79652133        0
# 2      0            0      79979                 0   39099598        0
# 3      0            0     151867                 0   62774297        0
# 4      0      2146742    5473852            366668  165784909  2758881
#
#    Biomass  Cents_kWh
# 0   151035      14.17
# 1  2147350       8.32
# 2  1253433      10.01
# 3   107888      11.58
# 4  6239901      13.21

# %% [markdown]
# ## Reordering and Transposing

# %% [markdown]
# Let's reorder our columns such that non-dispatchable are first, dispatchable are second, and intermittent are last. That way when we start plotting, the order of the stack will be meaningful, with non-dispatchable at the bottom of the plot, dispatchable in the middle, and intermittent at the top.

# %%
columns = ['Year', 'State', 'Coal', 'Nuclear',  'Petroleum',
           'Natural Gas',  'Other Gases', 'Other', 'Hydroelectric',
           'Geothermal', 'Biomass', 'Solar Thermal/PV', 'Wind', 'Total', 'Cents_kWh']
dfg=dfg.reindex(columns=columns)

# %% [markdown]
# ## Normalizing Generation Totals

# %% [markdown]
# Our generation data is given by EIA in megawatt hours (MWh). For our purposes we prefer the data to be scaled such that each generation source is expressed at a fraction of the state's total. The first step is to transpose the dataframe, as it is quite convenient to operate on columns:

# %%
dfg_transposed = dfg.T

# Here is an example of what one of the transposed rows looks like:
dfg_transposed[[0]]
# Out:
#                         0
# Year                 1990
# State                  AK
# Coal               510573
# Nuclear                 0
# Petroleum          497116
# Natural Gas       3466261
# Other Gases             0
# Other                   0
# Hydroelectric      974521
# Geothermal              0
# Biomass            151035
# Solar Thermal/PV        0
# Wind                    0
# Total             5599506
# Cents_kWh           14.17

# %% [markdown]
# This loop will normalize our generation data:

# %%
for i in range(len(dfg_transposed.columns)):
    dfg_transposed[i][2:14] = dfg_transposed[i][2:14] / dfg_transposed[i][13]

# %%
# Here is an example of a normalized column. Note that "Cents_kWh" is not altered:
dfg_transposed[[0]]
# Out:
#                           0
# Year                   1990
# State                    AK
# Coal              0.0911818
# Nuclear                   0
# Petroleum         0.0887785
# Natural Gas         0.61903
# Other Gases               0
# Other                     0
# Hydroelectric      0.174037
# Geothermal                0
# Biomass           0.0269729
# Solar Thermal/PV          0
# Wind                      0
# Total                     1
# Cents_kWh             14.17

# %% [markdown]
# Now we'll undo the transposition

# %%
dfg = dfg_transposed.T
dfg.head()
# Out:
#    Year State       Coal   Nuclear   Petroleum Natural Gas Other Gases Other  \
# 0  1990    AK  0.0911818         0   0.0887785     0.61903           0     0
# 1  1990    AL   0.673656  0.151306  0.00173365   0.0128146  0.00338316     0
# 2  1990    AR   0.491257  0.288547  0.00204552   0.0915245           0     0
# 3  1990    AZ   0.508418  0.328123  0.00241925   0.0371792           0     0
# 4  1990    CA  0.0159102    0.1972   0.0330178    0.447377    0.012949     0
#
#   Hydroelectric Geothermal     Biomass Solar Thermal/PV       Wind Total  \
# 0      0.174037          0   0.0269729                0          0     1
# 1      0.130147          0   0.0269591                0          0     1
# 2     0.0934703          0   0.0320574                0          0     1
# 3      0.118163          0  0.00171867                0          0     1
# 4      0.143515  0.0875909   0.0376385       0.00221171  0.0166413     1
#
#   Cents_kWh
# 0     14.17
# 1      8.32
# 2     10.01
# 3     11.58
# 4     13.21

# %% [markdown]
# We no longer need the 'Total" column. Its only purpose was to allow us to normalize, so we can safely drop it:

# %%
dfg.drop(columns='Total', inplace=True)

# %% [markdown]
# In the transposition, we lost our preferred datatypes, so we will reset them below:

# %%
dfg.dtypes.head()
# Out:
# Year         object
# State        object
# Coal         object
# Nuclear      object
# Petroleum    object
# dtype: object

# %%
cols = dfg.columns.drop('State')
dfg[cols] = dfg[cols].apply(pd.to_numeric, errors='coerce')

# %% [markdown]
# # Visualization

# %% [markdown]
# Here we define functions, to generate one or several stackplots, which will show us state generation profiles, and how they have changed over time:

# %%
def one_stackplot(dataframe, state, figsize1, figsize2):
    x = list(dataframe['Year'].unique())
    y = dataframe[dataframe['State'] == state].iloc[:, 2:13].T.values.tolist()
    cols = dfg.drop(columns=['Year', 'State', 'Cents_kWh']).columns.tolist()
    fig, ax = plt.subplots(figsize = (figsize1, figsize2))
    ax.stackplot(x, y, labels=cols, colors=['black', 'rebeccapurple', 'whitesmoke', 
                                         'silver', 'mistyrose', 'palegoldenrod',
                                         'royalblue', 'saddlebrown', 'green', 'gold', 'skyblue'])
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(reversed(handles), reversed(labels), loc='upper left')
    ax.set_title("{} Electricity Generation from 1990-2018".format(state), fontsize=20)
    ax.set_xlabel("Year", size=18)
    ax.set_ylabel("Generation Source", size=18)

# %%
one_stackplot(dfg, "CA", 18, 12)

# %% [markdown]
# **Interpretation**: California is an interesting case, as the state with the most progressive environmental policies for most of the time period analyzed. The two darkest, bottom colors represent coal (black) and nuclear (purple), which are non-dispatchable. These generation technologies pair poorly with intermittent sources of generation, wind (sky blue) and solar (yellow). In the middle section of the plot we have a variety of dispatchable sources of generation, with emissions-causing sources toward the bottom of the plot such as petroleum (thin white line), natual gas (gray), and other gases (pink). Hydroelectric (blue), geothermal (brown), and biomass (green) are both dispatchable and renewable.

# %%
def subplot_stackplots(dataframe, states, figsize1, figsize2):
    cols = dataframe.columns.drop(['Year', 'State', 'Cents_kWh']) # These three will not be in the "stack" part of our stackplot
    colors=['black', 'rebeccapurple', 'whitesmoke', # Color choices were extremely challenging
            'silver', 'mistyrose', 'palegoldenrod', # because we have a fairly complex stackplot
            'royalblue', 'saddlebrown', 'green',
            'gold', 'skyblue']
    nrows = int(np.ceil(len(states)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (figsize1, figsize2))
    ax = ax.ravel()
    for i, state in enumerate(states):
        x = list(dataframe['Year'].unique())
        y = dataframe[dataframe['State'] == state].iloc[:, 2:13].T.values.tolist()
        ax[i].stackplot(x, y, labels=cols, colors=colors)
        ax[i].set_title("{} Electricity Generation from 1990-2018".format(states[i]), size=20)
        ax[i].set_xlabel("Year", size=18)
        ax[i].set_ylabel("Generation Source", size=18)
        handles, labels = ax[i].get_legend_handles_labels()
        ax[i].legend(reversed(handles), reversed(labels), loc='upper left')
    plt.tight_layout(h_pad = 3, w_pad = 2)

# %%
subplot_stackplots(dfg, ['HI', 'ID', 'WV', 'NV'], 40, 32)

# %% [markdown]
# # Clustering States by Generation Profile

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
dfg.head()
# Out:
#    Year State      Coal   Nuclear  Petroleum  Natural Gas  Other Gases  Other  \
# 0  1990    AK  0.091182  0.000000   0.088779     0.619030     0.000000    0.0
# 1  1990    AL  0.673656  0.151306   0.001734     0.012815     0.003383    0.0
# 2  1990    AR  0.491257  0.288547   0.002046     0.091525     0.000000    0.0
# 3  1990    AZ  0.508418  0.328123   0.002419     0.037179     0.000000    0.0
# 4  1990    CA  0.015910  0.197200   0.033018     0.447377     0.012949    0.0
#
#    Hydroelectric  Geothermal   Biomass  Solar Thermal/PV      Wind  Cents_kWh
# 0       0.174037    0.000000  0.026973          0.000000  0.000000      14.17
# 1       0.130147    0.000000  0.026959          0.000000  0.000000       8.32
# 2       0.093470    0.000000  0.032057          0.000000  0.000000      10.01
# 3       0.118163    0.000000  0.001719          0.000000  0.000000      11.58
# 4       0.143515    0.087591  0.037639          0.002212  0.016641      13.21

# %%
year = 1990
X = dfg[dfg['Year'] == year].drop(columns=['Year', 'Cents_kWh']).set_index('State')
scores = []
for k in range(2, 7):
    cl = KMeans(n_clusters=k)
    cl.fit(X)
    inertia = cl.inertia_
    print(inertia)
    sil = silhouette_score(X, cl.labels_)
    scores.append([k, inertia, sil])
    
score_df = pd.DataFrame(scores)
score_df.columns = ['k', 'inertia', 'silhouette']
score_df.head()
# Out:
# 8.214356286160605
# 6.021410969606
# 4.386697673753851
# 3.058143788293786
# 2.2968777118300614
#    k   inertia  silhouette
# 0  2  8.214356    0.396270
# 1  3  6.021411    0.421616
# 2  4  4.386698    0.439213
# 3  5  3.058144    0.444878
# 4  6  2.296878    0.429417

# %%
cl = KMeans(n_clusters=6)
cl.fit(X)
X['KMClusters'] = cl.labels_
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
for i in range(cl.n_clusters):
    print(list(X[X['KMClusters'] == i].index))
# Out:
# ['ID', 'OR', 'SD', 'WA']
# ['CO', 'DE', 'IA', 'IN', 'KY', 'MD', 'MO', 'ND', 'NM', 'NV', 'OH', 'UT', 'WV', 'WY']
# ['AK', 'CA', 'LA', 'RI', 'TX']
# ['AL', 'AR', 'AZ', 'FL', 'GA', 'KS', 'MI', 'MN', 'MS', 'MT', 'NC', 'NE', 'OK', 'PA', 'TN', 'VA', 'WI']
# ['CT', 'IL', 'MA', 'ME', 'NH', 'NJ', 'NY', 'SC', 'VT']
# ['DC', 'HI']
